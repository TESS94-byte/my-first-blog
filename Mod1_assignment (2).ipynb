# %%
#3.1 assignment
60*60
# Out:
# 3600

# %%
#3.2 assignment
seconds_per_hour = 60*60
print(seconds_per_hour)
# Out:
# 3600

# %%
#3.3 assignment
seconds_per_hour * 24
# Out:
# 86400

# %%
#3.4 assignment
seconds_per_day = seconds_per_hour * 24
print('There are', seconds_per_hour, 'in a day')
# Out:
# There are 3600 in a day

# %%
#3.5 assignment
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
#3.6 assignment
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Yes. The results are the same. The only difference is that the floating-point division returns 24.0 because it includes a decimal point, while integer division returns an integer result the whole number 24, which reperesent the same value.
