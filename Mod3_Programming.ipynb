# %%
#7.4
things = ['mozzarella', 'cinderella', 'salmonella']
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
#7.5
things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# Yes. it changed the element in the list from "cindrella" to "Cindrella".

# %%
#7.6 
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
#7.7
del things[2]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
#9.1
def good():
    return['Harry' , 'Ron', 'Hermione']
print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
#9.2
def get_odds():
    for number in range(10):
        if number % 2 != 0 :
            yield number
count = 0
for number in get_odds():
    count += 1
    if count ==3: 
        print (number)
        break
# Out:
# 5
